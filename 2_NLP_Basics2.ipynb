# %% [markdown]
# <a href="https://colab.research.google.com/github/Akita20/Linear-Regression/blob/main/2_NLP_Basics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text = "Russia’s military 10th divion is trying to add to its gains in the south, moving closer to the vital port city of Odessa, as it tries to cut off the Ukrainian government from the sea. Outside Kyiv, there have been fierce attacks and counterattacks as Ukrainian forces battle to keep the Russians from encircling it. The vast armed convoy approaching Kyiv from the north still seems to be largely stalled, and the Ukrainian military says its forces have been attacking it where they can."

# %%
text
# Out:
# 'Russia’s military 10th divion is trying to add to its gains in the south, moving closer to the vital port city of Odessa, as it tries to cut off the Ukrainian government from the sea. Outside Kyiv, there have been fierce attacks and counterattacks as Ukrainian forces battle to keep the Russians from encircling it. The vast armed convoy approaching Kyiv from the north still seems to be largely stalled, and the Ukrainian military says its forces have been attacking it where they can.'

# %%
"Home"=="home"
# Out:
# False

# %%
# Normalize text
# NLTK considers capital letters and small letters differently.
# For example: Fox and fox are considered as two different words.
# Hence, we convert all letters of our text into lowercase.

# %%
text = text.lower()

# %%
print(text)
# Out:
# russia’s military 10th divion is trying to add to its gains in the south, moving closer to the vital port city of odessa, as it tries to cut off the ukrainian government from the sea. outside kyiv, there have been fierce attacks and counterattacks as ukrainian forces battle to keep the russians from encircling it. the vast armed convoy approaching kyiv from the north still seems to be largely stalled, and the ukrainian military says its forces have been attacking it where they can.

# %% [markdown]
# #### Tokenize Words
#
# #We split the text sentence/paragraph into a list of words. Each word in the list is called a token.

# %%
# tokenize text
words = word_tokenize(text)
print (words)
# Out:
# ['russia', '’', 's', 'military', '10th', 'divion', 'is', 'trying', 'to', 'add', 'to', 'its', 'gains', 'in', 'the', 'south', ',', 'moving', 'closer', 'to', 'the', 'vital', 'port', 'city', 'of', 'odessa', ',', 'as', 'it', 'tries', 'to', 'cut', 'off', 'the', 'ukrainian', 'government', 'from', 'the', 'sea', '.', 'outside', 'kyiv', ',', 'there', 'have', 'been', 'fierce', 'attacks', 'and', 'counterattacks', 'as', 'ukrainian', 'forces', 'battle', 'to', 'keep', 'the', 'russians', 'from', 'encircling', 'it', '.', 'the', 'vast', 'armed', 'convoy', 'approaching', 'kyiv', 'from', 'the', 'north', 'still', 'seems', 'to', 'be', 'largely', 'stalled', ',', 'and', 'the', 'ukrainian', 'military', 'says', 'its', 'forces', 'have', 'been', 'attacking', 'it', 'where', 'they', 'can', '.']

# %% [markdown]
# #### Removing Punctuation

# %% [markdown]
# #As you can see in the above output, there’s a token for full-stop (.).
#
# #It’s a punctuation mark. Generally, we get rid of such punctuation marks while analyzing text.

# %%
words = [w for w in words if w.isalpha()]

# %%
print(words)
# Out:
# ['russia', 's', 'military', 'divion', 'is', 'trying', 'to', 'add', 'to', 'its', 'gains', 'in', 'the', 'south', 'moving', 'closer', 'to', 'the', 'vital', 'port', 'city', 'of', 'odessa', 'as', 'it', 'tries', 'to', 'cut', 'off', 'the', 'ukrainian', 'government', 'from', 'the', 'sea', 'outside', 'kyiv', 'there', 'have', 'been', 'fierce', 'attacks', 'and', 'counterattacks', 'as', 'ukrainian', 'forces', 'battle', 'to', 'keep', 'the', 'russians', 'from', 'encircling', 'it', 'the', 'vast', 'armed', 'convoy', 'approaching', 'kyiv', 'from', 'the', 'north', 'still', 'seems', 'to', 'be', 'largely', 'stalled', 'and', 'the', 'ukrainian', 'military', 'says', 'its', 'forces', 'have', 'been', 'attacking', 'it', 'where', 'they', 'can']

# %% [markdown]
# #### Removing Stop Words

# %% [markdown]
# Here, we will remove stop words from our text data using the default stopwords corpus present in NLTK.

# %% [markdown]
# #### Get list of English Stopwords

# %%
stop_words = stopwords.words('english')

# %%
# creating a copy of the words list
words_filtered = words[:]

# %%
for word in words:
    if word in stop_words:
        words_filtered.remove(word)
print (words_filtered)
# Out:
# ['russia', 'military', 'divion', 'trying', 'add', 'gains', 'south', 'moving', 'closer', 'vital', 'port', 'city', 'odessa', 'tries', 'cut', 'ukrainian', 'government', 'sea', 'outside', 'kyiv', 'fierce', 'attacks', 'counterattacks', 'ukrainian', 'forces', 'battle', 'keep', 'russians', 'encircling', 'vast', 'armed', 'convoy', 'approaching', 'kyiv', 'north', 'still', 'seems', 'largely', 'stalled', 'ukrainian', 'military', 'says', 'forces', 'attacking']

# %% [markdown]
# #### Updating Stop Words Corpus

# %% [markdown]
# Suppose, you don’t want to omit some stopwords for your text analysis. In such case, you have to remove those words from the stopwords list.
#
# Let’s suppose, you want the words over and under for your text analysis. The words “over” and “under” are present in the stopwords corpus by default. Let’s remove them from the stopwords corpus.

# %%
# set() function removes duplicate entries from the list
stop_words = set(stopwords.words('english')) - set(['over', 'under'])

#stopwords_english = [str(item) for item in stop_words]
#print (stopwords_english)

print (stop_words)
# Out:
# {'herself', 'not', 'by', 'of', "should've", 'as', 'our', 'have', "shouldn't", 'so', 'too', 'himself', 'most', 'they', "she's", 'she', 'into', 'there', 'when', 'those', "hadn't", 'mightn', 'during', 'aren', 'should', 'to', 'after', 'where', 'hadn', 'below', 'am', 'm', "couldn't", "you're", 'at', 'why', 'o', 'but', 'needn', 'can', 'your', 'it', 'between', 'an', 'ain', 'its', "mightn't", 'for', 'own', 'than', "that'll", 'these', 'hasn', 'weren', 'what', 'that', 'such', 'through', 'only', 'wouldn', 'just', 'don', 'll', 'off', 'few', 'again', 'you', 'being', 'was', "didn't", 'be', 'from', 'haven', 'about', 'whom', 'each', "don't", 'some', 'his', 've', 'him', 'who', 'does', 'ourselves', 'doing', 'them', 'or', 'all', 'shan', 'very', "needn't", 'while', 'in', 'on', 'then', "wasn't", 're', "you'd", 'yourselves', 'has', 't', 'ours', "weren't", "wouldn't", 'more', 'he', 'any', 'other', 'with', 'because', 'both', 'we', "hasn't", "you'll", 'me', 'up', 'my', 'same', 'doesn', 'y', "doesn't", 'their', "haven't", 'here', 'yourself', 'themselves', 'nor', 'isn', 'ma', 'were', 'if', 'no', 'how', 'further', 'are', 'had', 'won', 'out', 'shouldn', 'which', 'do', 'the', 'yours', 'and', "you've", 'hers', 'will', 'until', 'couldn', 'been', 'didn', 'mustn', "won't", 'down', 'is', "isn't", 'her', "mustn't", 'a', 'itself', 'this', 'd', "shan't", 'wasn', 'theirs', "it's", 'did', 'before', 'i', 'above', 's', 'against', 'now', 'once', "aren't", 'having', 'myself'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
