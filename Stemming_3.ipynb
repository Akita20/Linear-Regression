# %% [markdown]
# <a href="https://colab.research.google.com/github/Akita20/Linear-Regression/blob/main/Stemming_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #### NLTK - stemming
# Start by defining some words:

# %%
words = ["game","gaming","gamed","games"]

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer() # remove suffex from the word

# %%
for word in words:
    print(ps.stem(word))
# Out:
# game
# game
# game
# game

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Example2

# %%
sentence = "gaming, the gamers play games"

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
words = word_tokenize(sentence)

# %%
print(words)
# Out:
# ['gaming', ',', 'the', 'gamers', 'play', 'games']

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
ps.stem(word)
# Out:
# 'game'

# %%
for word in words:
    print(word + ":" + ps.stem(word))
# Out:
# gaming:game
# ,:,
# the:the
# gamers:gamer
# play:play
# games:game

# %% [markdown]
# #### Stemming with NLTK
# There are more stemming algorithms, but Porter (PorterStemer) is the most popular.

# %% [markdown]
# #### Example3

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
text = "Russia’s military is trying to add to its gains in the south, moving closer to the vital port city of Odessa, as it tries to cut off the Ukrainian government from the sea. Outside Kyiv, there have been fierce attacks and counterattacks as Ukrainian forces battle to keep the Russians from encircling it. The vast armed convoy approaching Kyiv from the north still seems to be largely stalled, and the Ukrainian military says its forces have been attacking it where they can."

# %%
text = text.lower()

# %%
# tokenize text
words = word_tokenize(text)

print (words)
# Out:
# ['russia', '’', 's', 'military', 'is', 'trying', 'to', 'add', 'to', 'its', 'gains', 'in', 'the', 'south', ',', 'moving', 'closer', 'to', 'the', 'vital', 'port', 'city', 'of', 'odessa', ',', 'as', 'it', 'tries', 'to', 'cut', 'off', 'the', 'ukrainian', 'government', 'from', 'the', 'sea', '.', 'outside', 'kyiv', ',', 'there', 'have', 'been', 'fierce', 'attacks', 'and', 'counterattacks', 'as', 'ukrainian', 'forces', 'battle', 'to', 'keep', 'the', 'russians', 'from', 'encircling', 'it', '.', 'the', 'vast', 'armed', 'convoy', 'approaching', 'kyiv', 'from', 'the', 'north', 'still', 'seems', 'to', 'be', 'largely', 'stalled', ',', 'and', 'the', 'ukrainian', 'military', 'says', 'its', 'forces', 'have', 'been', 'attacking', 'it', 'where', 'they', 'can', '.']

# %%
stemmer = PorterStemmer()

# %%
words_stem = []
for word in words:
    words_stem.append(stemmer.stem(word))

# %%
print(words_stem)
# Out:
# ['russia', '’', 's', 'militari', 'is', 'tri', 'to', 'add', 'to', 'it', 'gain', 'in', 'the', 'south', ',', 'move', 'closer', 'to', 'the', 'vital', 'port', 'citi', 'of', 'odessa', ',', 'as', 'it', 'tri', 'to', 'cut', 'off', 'the', 'ukrainian', 'govern', 'from', 'the', 'sea', '.', 'outsid', 'kyiv', ',', 'there', 'have', 'been', 'fierc', 'attack', 'and', 'counterattack', 'as', 'ukrainian', 'forc', 'battl', 'to', 'keep', 'the', 'russian', 'from', 'encircl', 'it', '.', 'the', 'vast', 'arm', 'convoy', 'approach', 'kyiv', 'from', 'the', 'north', 'still', 'seem', 'to', 'be', 'larg', 'stall', ',', 'and', 'the', 'ukrainian', 'militari', 'say', 'it', 'forc', 'have', 'been', 'attack', 'it', 'where', 'they', 'can', '.']

# %%
#  a shorter version of the above code

# %%
words_stem = [stemmer.stem(word) for word in words]

# %% [markdown]
# #### Using split() function

# %% [markdown]
# #### Note: Tokenizing sentences into words is useful as it separates punctuations from the words. In below example, the last word dog will be taken as dog. (with full-stop at the end). The punctuation mark is not separated from the word.

# %%
from nltk.stem import PorterStemmer # stemming convers a woed into its root
stemmer = PorterStemmer()
text = "A quick brown fox jumps over the lazy dog."
text_stem = " ".join([stemmer.stem(word) for word in text.split()])
print (text_stem)
# Out:
# a quick brown fox jump over the lazi dog.

# %% [markdown]
# #### Stemming Non-English Words

# %% [markdown]
# There are other different stemmers like:
#
# * SnowballStemmer, LancasterStemmer, ISRIStemmer, RSLPStemmer, RegexpStemmer.

# %% [markdown]
# Stemming Spanish Words using SnowballStemmer​
#
# Let’s stem some Spanish words.​
#
# Here’s the English translation of the Spanish words:

# %% [raw]
# trabajando => working
# trabajos => works
# trabajó => worked

# %%
# -*- coding: utf-8 -*-
# The above line is added to solve the following error:
# SyntaxError: Non-ASCII character '\xc3' in file

from nltk.stem import SnowballStemmer

stemmer_spanish = SnowballStemmer('spanish')

print (stemmer_spanish.stem('trabajando')) # output: trabaj
print (stemmer_spanish.stem('trabajos')) # output: trabaj
#print (stemmer_spanish.stem('trabajó'.decode('utf-8'))) # output: trabaj

# UTF-8 decode is done to solve the following error:
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3
# Out:
# trabaj
# trabaj

# %% [markdown]
# #### Stemming English Words using SnowballStemmer

# %%
stemmer_english = SnowballStemmer('english')
print (stemmer_english.stem('working')) # output: work
print (stemmer_english.stem('works')) # output: work
print (stemmer_english.stem('worked')) # output: work
# Out:
# work
# work
# work

# %% [markdown]
# ![image.png](data:image/png;base64,...)
